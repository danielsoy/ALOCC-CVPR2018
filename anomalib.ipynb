# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsoy/ALOCC-CVPR2018/blob/master/anomalib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/openvinotoolkit/anomalib
#
# About:
# An anomaly detection library comprising state-of-the-art algorithms and features such as experiment management, hyper-parameter optimization, and edge inference.

# %%
# !git clone https://github.com/openvinotoolkit/anomalib.git
# Out:
# Cloning into 'anomalib'...
# remote: Enumerating objects: 3449, done.
# remote: Counting objects: 100% (1430/1430), done.
# remote: Compressing objects: 100% (476/476), done.
# remote: Total 3449 (delta 991), reused 1100 (delta 839), pack-reused 2019
# Receiving objects: 100% (3449/3449), 4.13 MiB | 15.33 MiB/s, done.
# Resolving deltas: 100% (1935/1935), done.

# %%
# %cd /content/anomalib/requirements
# Out:
# /content/anomalib/requirements

# %%
# !pip install -r base.txt

# %%
# !pip install -r dev.txt

# %%
# !pip install -r docs.txt

# %%
# !pip install -r openvino.txt

# %%
# !pip install -r base.txt
# !pip install -r dev.txt
# !pip install -r docs.txt
# !pip install -r openvino.txt
# Out:
# Collecting FrEIA@ git+https://github.com/VLL-HD/FrEIA.git
#   Cloning https://github.com/VLL-HD/FrEIA.git to /tmp/pip-install-nltocj_r/freia_df31d3c085ae468f927552fdfa1f4bf6
#   Running command git clone -q https://github.com/VLL-HD/FrEIA.git /tmp/pip-install-nltocj_r/freia_df31d3c085ae468f927552fdfa1f4bf6
# Collecting albumentations==1.1.0
#   Downloading albumentations-1.1.0-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 7.4 MB/s
# Collecting attrdict==2.0.1
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.7/dist-packages (from -r base.txt (line 3)) (0.7.1)
# Collecting einops==0.3.2
#   Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Collecting kornia==0.5.6
#   Downloading kornia-0.5.6-py2.py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 57.3 MB/s
# Collecting lxml==4.6.5
#   Downloading lxml-4.6.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 59.3 MB/s
# Collecting matplotlib==3.4.3
#   Downloading matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 69.8 MB/s
# Requirement already satisfied: networkx~=2.5 in /usr/local/lib/python3.7/dist-packages (from -r base.txt (line 9)) (2.6.3)
# Collecting nncf==2.0.0
#   Downloading nncf-2.0.0-py3-none-any.whl (559 kB)
#      |████████████████████████████████| 559 kB 75.5 MB/s
# Requirement already satisfied: numpy~=1.19.5 in /usr/local/lib/python3.7/dist-packages (from -r base.txt (line 11)) (1.19.5)
# Collecting omegaconf==2.1.1
#   Downloading omegaconf-2.1.1-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 4.3 MB/s
# Collecting pillow==8.3.2
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 61.4 MB/s
# Collecting pytorch-lightning==1.3.6
#   Downloading pytorch_lightning-1.3.6-py3-none-any.whl (809 kB)
#      |████████████████████████████████| 809 kB 56.2 MB/s
# Collecting torch==1.8.1
#   Downloading torch-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (804.1 MB)
#      |████████████████████████████████| 804.1 MB 2.6 kB/s
# Collecting torchvision==0.9.1
#   Downloading torchvision-0.9.1-cp37-cp37m-manylinux1_x86_64.whl (17.4 MB)
#      |████████████████████████████████| 17.4 MB 578 kB/s
# Requirement already satisfied: scikit-image>=0.17.2 in /usr/local/lib/python3.7/dist-packages (from -r base.txt (line 17)) (0.18.3)
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 99.1 MB/s
# Collecting wandb==0.12.9
#   Downloading wandb-0.12.9-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 60.7 MB/s
# Collecting scipy>=1.5
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# Collecting qudida>=0.0.4
#   Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Collecting opencv-python-headless>=4.1.1
#   Downloading opencv_python_headless-4.5.5.62-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.7 MB)
#      |████████████████████████████████| 47.7 MB 63 kB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from albumentations==1.1.0->-r base.txt (line 1)) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from attrdict==2.0.1->-r base.txt (line 2)) (1.15.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4.3->-r base.txt (line 8)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4.3->-r base.txt (line 8)) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4.3->-r base.txt (line 8)) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4.3->-r base.txt (line 8)) (2.8.2)
# Requirement already satisfied: wheel>=0.36.1 in /usr/local/lib/python3.7/dist-packages (from nncf==2.0.0->-r base.txt (line 10)) (0.37.1)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from nncf==2.0.0->-r base.txt (line 10)) (1.1.5)
# Collecting texttable>=1.6.3
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Collecting addict>=2.4.0
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Collecting pydot>=1.4.1
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting jstyleson>=0.0.2
#   Downloading jstyleson-0.0.2.tar.gz (2.0 kB)
# Requirement already satisfied: tqdm>=4.54.1 in /usr/local/lib/python3.7/dist-packages (from nncf==2.0.0->-r base.txt (line 10)) (4.62.3)
# Collecting natsort>=7.1.0
#   Downloading natsort-8.0.2-py3-none-any.whl (37 kB)
# Collecting jsonschema==3.2.0
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.8 MB/s
# Collecting ninja>=1.10.0.post2
#   Downloading ninja-1.10.2.3-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (108 kB)
#      |████████████████████████████████| 108 kB 68.2 MB/s
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 74.4 MB/s
# Collecting antlr4-python3-runtime==4.8
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      |████████████████████████████████| 112 kB 80.9 MB/s
# Requirement already satisfied: tensorboard!=2.5.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.3.6->-r base.txt (line 14)) (2.7.0)
# Collecting PyYAML
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 63.7 MB/s
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 73.7 MB/s
# Collecting pyDeprecate==0.3.0
#   Downloading pyDeprecate-0.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.3.6->-r base.txt (line 14)) (21.3)
# Collecting torchmetrics>=0.2.0
#   Downloading torchmetrics-0.6.2-py3-none-any.whl (332 kB)
#      |████████████████████████████████| 332 kB 70.3 MB/s
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 82.3 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1->-r base.txt (line 15)) (3.10.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2->-r base.txt (line 18)) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2->-r base.txt (line 18)) (1.1.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.9->-r base.txt (line 19)) (2.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.9->-r base.txt (line 19)) (5.4.8)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.26-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 77.7 MB/s
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.9->-r base.txt (line 19)) (7.1.2)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.9->-r base.txt (line 19)) (3.17.3)
# Collecting subprocess32>=3.5.3
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 8.4 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.2-py2.py3-none-any.whl (142 kB)
#      |████████████████████████████████| 142 kB 59.5 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting yaspin>=1.0.0
#   Downloading yaspin-2.1.0-py3-none-any.whl (18 kB)
# Collecting configparser>=3.8.1
#   Downloading configparser-5.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.9->-r base.txt (line 19)) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2.0->nncf==2.0.0->-r base.txt (line 10)) (57.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2.0->nncf==2.0.0->-r base.txt (line 10)) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2.0->nncf==2.0.0->-r base.txt (line 10)) (0.18.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2.0->nncf==2.0.0->-r base.txt (line 10)) (4.10.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.17.2->-r base.txt (line 17)) (1.2.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.17.2->-r base.txt (line 17)) (2021.11.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.17.2->-r base.txt (line 17)) (2.4.1)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 54.6 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.4 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->nncf==2.0.0->-r base.txt (line 10)) (2018.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb==0.12.9->-r base.txt (line 19)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb==0.12.9->-r base.txt (line 19)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb==0.12.9->-r base.txt (line 19)) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb==0.12.9->-r base.txt (line 19)) (2.10)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (1.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (0.12.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema==3.2.0->nncf==2.0.0->-r base.txt (line 10)) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (3.1.1)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb==0.12.9->-r base.txt (line 19)) (1.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 74.8 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 71.2 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 74.8 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.3.6->-r base.txt (line 14)) (2.0.10)
# Building wheels for collected packages: FrEIA, antlr4-python3-runtime, future, jstyleson, subprocess32, pathtools
#   Building wheel for FrEIA (setup.py) ... done
#   Created wheel for FrEIA: filename=FrEIA-0.2-py3-none-any.whl size=49896 sha256=9659c707f1dcd8e90d648abdfd32a82c441b42b48d59fdee3e1902b6a9ce8119
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2ef3ktkl/wheels/ce/20/ea/82f4b732f0705014bd0b340c3375d25aa89491a98a49ec4b8f
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141230 sha256=ed2dbfddf05d89914f91e455763348bb034079122ec144260760d1e939695ff1
#   Stored in directory: /root/.cache/pip/wheels/ca/33/b7/336836125fc9bb4ceaa4376d8abca10ca8bc84ddc824baea6c
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=6c58541d1adb781b933cc6c330319df8b57dab6cc1daf545f13c01353118033a
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for jstyleson (setup.py) ... done
#   Created wheel for jstyleson: filename=jstyleson-0.0.2-py3-none-any.whl size=2402 sha256=e4a67a5a4989fa7db344f5107824b555b266eeeeb048ebb46c7b2c9376936329
#   Stored in directory: /root/.cache/pip/wheels/be/8e/03/d5962b9032cc1b638d1891a3bfbfdc6627cac531754f79ef23
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=1a39c6ab728873d5224073c1526b9099deb92d72aeb5b7ac7433ab37ff69a0fc
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=2f6ff232994c582bd521e2d5c98aeefd9b5b537e7fd98ef5ff208bcc9e30a595
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built FrEIA antlr4-python3-runtime future jstyleson subprocess32 pathtools
# Installing collected packages: multidict, frozenlist, yarl, smmap, scipy, pillow, asynctest, async-timeout, aiosignal, torch, scikit-learn, opencv-python-headless, matplotlib, gitdb, fsspec, aiohttp, yaspin, torchmetrics, texttable, subprocess32, shortuuid, sentry-sdk, qudida, PyYAML, pydot, pyDeprecate, pathtools, ninja, natsort, jstyleson, jsonschema, GitPython, future, docker-pycreds, configparser, antlr4-python3-runtime, addict, wandb, torchvision, pytorch-lightning, omegaconf, nncf, lxml, kornia, FrEIA, einops, attrdict, albumentations
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pydot
#     Found existing installation: pydot 1.3.0
#     Uninstalling pydot-1.3.0:
#       Successfully uninstalled pydot-1.3.0
#   Attempting uninstall: natsort
#     Found existing installation: natsort 5.5.0
#     Uninstalling natsort-5.5.0:
#       Successfully uninstalled natsort-5.5.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 0.1.12
#     Uninstalling albumentations-0.1.12:
#       Successfully uninstalled albumentations-0.1.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.8.1 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.8.1 which is incompatible.
# nbclient 0.5.9 requires jupyter-client>=6.1.5, but you have jupyter-client 5.3.5 which is incompatible.
# Successfully installed FrEIA-0.2 GitPython-3.1.26 PyYAML-5.4.1 addict-2.4.0 aiohttp-3.8.1 aiosignal-1.2.0 albumentations-1.1.0 antlr4-python3-runtime-4.8 async-timeout-4.0.2 asynctest-0.13.0 attrdict-2.0.1 configparser-5.2.0 docker-pycreds-0.4.0 einops-0.3.2 frozenlist-1.2.0 fsspec-2022.1.0 future-0.18.2 gitdb-4.0.9 jsonschema-3.2.0 jstyleson-0.0.2 kornia-0.5.6 lxml-4.6.5 matplotlib-3.4.3 multidict-5.2.0 natsort-8.0.2 ninja-1.10.2.3 nncf-2.0.0 omegaconf-2.1.1 opencv-python-headless-4.5.5.62 pathtools-0.1.2 pillow-8.3.2 pyDeprecate-0.3.0 pydot-1.4.2 pytorch-lightning-1.3.6 qudida-0.0.4 scikit-learn-0.24.2 scipy-1.7.3 sentry-sdk-1.5.2 shortuuid-1.0.8 smmap-5.0.0 subprocess32-3.5.4 texttable-1.6.4 torch-1.8.1 torchmetrics-0.6.2 torchvision-0.9.1 wandb-0.12.9 yarl-1.7.2 yaspin-2.1.0
# Collecting black
#   Downloading black-21.12b0-py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 7.5 MB/s
# Requirement already satisfied: coverage in /usr/local/lib/python3.7/dist-packages (from -r dev.txt (line 2)) (3.7.1)
# Collecting flake8
#   Downloading flake8-4.0.1-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.6 MB/s
# Collecting flaky
#   Downloading flaky-3.7.0-py2.py3-none-any.whl (22 kB)
# Collecting isort
#   Downloading isort-5.10.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 73.8 MB/s
# Collecting mypy
#   Downloading mypy-0.931-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 71.2 MB/s
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from -r dev.txt (line 7)) (3.6.4)
# Collecting pylint
#   Downloading pylint-2.12.2-py3-none-any.whl (414 kB)
#      |████████████████████████████████| 414 kB 77.0 MB/s
# Collecting pre-commit>=2.15.0
#   Downloading pre_commit-2.16.0-py2.py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 62.0 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from -r dev.txt (line 10)) (57.4.0)
# Collecting tox>=3.24.3
#   Downloading tox-3.24.5-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 6.1 MB/s
# Collecting types-PyYAML
#   Downloading types_PyYAML-6.0.3-py3-none-any.whl (13 kB)
# Collecting types-setuptools
#   Downloading types_setuptools-57.4.7-py3-none-any.whl (27 kB)
# Collecting nodeenv>=0.11.1
#   Downloading nodeenv-1.6.0-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from pre-commit>=2.15.0->-r dev.txt (line 9)) (5.4.1)
# Collecting virtualenv>=20.0.8
#   Downloading virtualenv-20.13.0-py2.py3-none-any.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 57.3 MB/s
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pre-commit>=2.15.0->-r dev.txt (line 9)) (0.10.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from pre-commit>=2.15.0->-r dev.txt (line 9)) (4.10.0)
# Collecting cfgv>=2.0.0
#   Downloading cfgv-3.3.1-py2.py3-none-any.whl (7.3 kB)
# Collecting identify>=1.0.0
#   Downloading identify-2.4.3-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 10.3 MB/s
# Requirement already satisfied: py>=1.4.17 in /usr/local/lib/python3.7/dist-packages (from tox>=3.24.3->-r dev.txt (line 11)) (1.11.0)
# Requirement already satisfied: filelock>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from tox>=3.24.3->-r dev.txt (line 11)) (3.4.2)
# Requirement already satisfied: packaging>=14 in /usr/local/lib/python3.7/dist-packages (from tox>=3.24.3->-r dev.txt (line 11)) (21.3)
# Collecting pluggy>=0.12.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from tox>=3.24.3->-r dev.txt (line 11)) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->pre-commit>=2.15.0->-r dev.txt (line 9)) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->pre-commit>=2.15.0->-r dev.txt (line 9)) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14->tox>=3.24.3->-r dev.txt (line 11)) (3.0.6)
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.4.1-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.4-py2.py3-none-any.whl (461 kB)
#      |████████████████████████████████| 461 kB 74.4 MB/s
# Collecting typed-ast>=1.4.2
#   Downloading typed_ast-1.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 72.3 MB/s
# Collecting pathspec<1,>=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting tomli<2.0.0,>=0.2.6
#   Downloading tomli-1.2.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: click>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from black->-r dev.txt (line 1)) (7.1.2)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# Collecting pyflakes<2.5.0,>=2.4.0
#   Downloading pyflakes-2.4.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 9.8 MB/s
# Collecting pycodestyle<2.9.0,>=2.8.0
#   Downloading pycodestyle-2.8.0-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.1 MB/s
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pytest
#   Downloading pytest-6.2.5-py3-none-any.whl (280 kB)
#      |████████████████████████████████| 280 kB 76.0 MB/s
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest->-r dev.txt (line 7)) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r dev.txt (line 7)) (21.4.0)
# Collecting astroid<2.10,>=2.9.0
#   Downloading astroid-2.9.3-py3-none-any.whl (254 kB)
#      |████████████████████████████████| 254 kB 75.2 MB/s
# Requirement already satisfied: wrapt<1.14,>=1.11 in /usr/local/lib/python3.7/dist-packages (from astroid<2.10,>=2.9.0->pylint->-r dev.txt (line 8)) (1.13.3)
# Collecting lazy-object-proxy>=1.4.0
#   Downloading lazy_object_proxy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.8 MB/s
# Installing collected packages: typed-ast, platformdirs, lazy-object-proxy, importlib-metadata, distlib, virtualenv, tomli, pyflakes, pycodestyle, pluggy, pathspec, nodeenv, mypy-extensions, mccabe, isort, identify, cfgv, astroid, types-setuptools, types-PyYAML, tox, pytest, pylint, pre-commit, mypy, flaky, flake8, black
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.10.0
#     Uninstalling importlib-metadata-4.10.0:
#       Successfully uninstalled importlib-metadata-4.10.0
#   Attempting uninstall: tomli
#     Found existing installation: tomli 2.0.0
#     Uninstalling tomli-2.0.0:
#       Successfully uninstalled tomli-2.0.0
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.6 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed astroid-2.9.3 black-21.12b0 cfgv-3.3.1 distlib-0.3.4 flake8-4.0.1 flaky-3.7.0 identify-2.4.3 importlib-metadata-4.2.0 isort-5.10.1 lazy-object-proxy-1.7.1 mccabe-0.6.1 mypy-0.931 mypy-extensions-0.4.3 nodeenv-1.6.0 pathspec-0.9.0 platformdirs-2.4.1 pluggy-1.0.0 pre-commit-2.16.0 pycodestyle-2.8.0 pyflakes-2.4.0 pylint-2.12.2 pytest-6.2.5 tomli-1.2.3 tox-3.24.5 typed-ast-1.5.1 types-PyYAML-6.0.3 types-setuptools-57.4.7 virtualenv-20.13.0
# Collecting furo==2021.7.31b41
#   Downloading furo-2021.7.31b41-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 4.7 MB/s
# Collecting myst-parser
#   Downloading myst_parser-0.16.1-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 7.3 MB/s
# Collecting sphinx>=4.1.2
#   Downloading Sphinx-4.3.2-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 18.8 MB/s
# Collecting sphinx-autoapi
#   Downloading sphinx_autoapi-1.8.4-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.7 MB/s
# Collecting sphinxemoji==0.1.8
#   Downloading sphinxemoji-0.1.8.tar.gz (40 kB)
#      |████████████████████████████████| 40 kB 6.4 MB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from furo==2021.7.31b41->-r docs.txt (line 1)) (4.6.3)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (2.2.0)
# Requirement already satisfied: docutils<0.18,>=0.14 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (0.17.1)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (2.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (57.4.0)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 64.8 MB/s
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (0.7.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (21.3)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (2.11.3)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (1.3.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (1.1.5)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 12.6 MB/s
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (2.23.0)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 4.4 MB/s
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 12.4 MB/s
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.1.2->-r docs.txt (line 3)) (2.6.1)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/dist-packages (from babel>=1.3->sphinx>=4.1.2->-r docs.txt (line 3)) (2018.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.3->sphinx>=4.1.2->-r docs.txt (line 3)) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sphinx>=4.1.2->-r docs.txt (line 3)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sphinx>=4.1.2->-r docs.txt (line 3)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sphinx>=4.1.2->-r docs.txt (line 3)) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sphinx>=4.1.2->-r docs.txt (line 3)) (2.10)
# Collecting markdown-it-py<3.0.0,>=1.0.0
#   Downloading markdown_it_py-2.0.0-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 3.4 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from myst-parser->-r docs.txt (line 2)) (5.4.1)
# Collecting mdit-py-plugins~=0.3.0
#   Downloading mdit_py_plugins-0.3.0-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.6 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from markdown-it-py<3.0.0,>=1.0.0->myst-parser->-r docs.txt (line 2)) (3.10.0.2)
# Requirement already satisfied: attrs<22,>=19 in /usr/local/lib/python3.7/dist-packages (from markdown-it-py<3.0.0,>=1.0.0->myst-parser->-r docs.txt (line 2)) (21.4.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: astroid>=2.7 in /usr/local/lib/python3.7/dist-packages (from sphinx-autoapi->-r docs.txt (line 4)) (2.9.3)
# Collecting unidecode
#   Downloading Unidecode-1.3.2-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 73.7 MB/s
# Requirement already satisfied: lazy-object-proxy>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from astroid>=2.7->sphinx-autoapi->-r docs.txt (line 4)) (1.7.1)
# Requirement already satisfied: wrapt<1.14,>=1.11 in /usr/local/lib/python3.7/dist-packages (from astroid>=2.7->sphinx-autoapi->-r docs.txt (line 4)) (1.13.3)
# Requirement already satisfied: typed-ast<2.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from astroid>=2.7->sphinx-autoapi->-r docs.txt (line 4)) (1.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->sphinx>=4.1.2->-r docs.txt (line 3)) (3.0.6)
# Building wheels for collected packages: sphinxemoji
#   Building wheel for sphinxemoji (setup.py) ... done
#   Created wheel for sphinxemoji: filename=sphinxemoji-0.1.8-py3-none-any.whl size=39866 sha256=7bfd7943c94ca4313ca7fb84f80b27fb5a48d592342dd467d45bd1ee4487ee70
#   Stored in directory: /root/.cache/pip/wheels/46/19/0e/082d2eb0e41a9973a8cd2512a80145fe37759546ed3114e2b4
# Successfully built sphinxemoji
# Installing collected packages: mdurl, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, markdown-it-py, unidecode, sphinx, mdit-py-plugins, sphinxemoji, sphinx-autoapi, myst-parser, furo
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 1.8.6
#     Uninstalling Sphinx-1.8.6:
#       Successfully uninstalled Sphinx-1.8.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed furo-2021.7.31b41 markdown-it-py-2.0.0 mdit-py-plugins-0.3.0 mdurl-0.1.0 myst-parser-0.16.1 sphinx-4.3.2 sphinx-autoapi-1.8.4 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxemoji-0.1.8 unidecode-1.3.2
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.7/dist-packages (from -r openvino.txt (line 1)) (0.7.1)
# Collecting requests==2.26.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 614 kB/s
# Requirement already satisfied: networkx~=2.5 in /usr/local/lib/python3.7/dist-packages (from -r openvino.txt (line 3)) (2.6.3)
# Collecting onnx==1.10.1
#   Downloading onnx-1.10.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (12.3 MB)
#      |████████████████████████████████| 12.3 MB 9.7 MB/s
# Collecting opencv-python==4.5.3.56
#   Downloading opencv_python-4.5.3.56-cp37-cp37m-manylinux2014_x86_64.whl (49.9 MB)
#      |████████████████████████████████| 49.9 MB 40 kB/s
# Collecting openvino-dev==2021.4.2
#   Downloading openvino_dev-2021.4.2-3976-py3-none-any.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 30.0 MB/s
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests==2.26.0->-r openvino.txt (line 2)) (2.0.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests==2.26.0->-r openvino.txt (line 2)) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests==2.26.0->-r openvino.txt (line 2)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests==2.26.0->-r openvino.txt (line 2)) (2021.10.8)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from onnx==1.10.1->-r openvino.txt (line 4)) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from onnx==1.10.1->-r openvino.txt (line 4)) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx==1.10.1->-r openvino.txt (line 4)) (3.10.0.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from onnx==1.10.1->-r openvino.txt (line 4)) (3.17.3)
# Requirement already satisfied: scikit-image>=0.17.2 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (0.18.3)
# Collecting progress>=1.5
#   Downloading progress-1.6.tar.gz (7.8 kB)
# Requirement already satisfied: jstyleson~=0.0.2 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (0.0.2)
# Requirement already satisfied: tqdm>=4.54.1 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (4.62.3)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (1.8.0)
# Collecting sentencepiece>=0.1.95
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 52.5 MB/s
# Collecting openvino==2021.4.2
#   Downloading openvino-2021.4.2-3976-cp37-cp37m-manylinux2014_x86_64.whl (28.9 MB)
#      |████████████████████████████████| 28.9 MB 1.2 MB/s
# Collecting pydicom>=2.1.2
#   Downloading pydicom-2.2.2-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 58.6 MB/s
# Collecting rawpy>=0.16.0
#   Downloading rawpy-0.17.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 66.6 MB/s
# Requirement already satisfied: pillow>=8.1.2 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (8.3.2)
# Collecting nltk>=3.5
#   Downloading nltk-3.6.7-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 61.0 MB/s
# Collecting scipy~=1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 89.3 MB/s
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (0.24.2)
# Collecting tokenizers>=0.10.1
#   Downloading tokenizers-0.11.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 64.9 MB/s
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (5.4.1)
# Requirement already satisfied: hyperopt~=0.1.2 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (0.1.2)
# Requirement already satisfied: addict>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (2.4.0)
# Collecting nibabel>=3.2.1
#   Downloading nibabel-3.2.1-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 65.5 MB/s
# Collecting fast-ctc-decode>=0.2.5
#   Downloading fast_ctc_decode-0.3.0-cp37-cp37m-manylinux2010_x86_64.whl (508 kB)
#      |████████████████████████████████| 508 kB 67.3 MB/s
# Collecting py-cpuinfo>=7.0.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 11.3 MB/s
# Requirement already satisfied: editdistance>=0.5.3 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (0.5.3)
# Collecting parasail>=1.2.4
#   Downloading parasail-1.2.4-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 22.1 MB/s
# Requirement already satisfied: texttable~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (1.6.4)
# Requirement already satisfied: pandas~=1.1.5 in /usr/local/lib/python3.7/dist-packages (from openvino-dev==2021.4.2->-r openvino.txt (line 6)) (1.1.5)
# Collecting yamlloader>=0.5
#   Downloading yamlloader-1.1.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (from hyperopt~=0.1.2->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (4.0.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt~=0.1.2->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (0.18.2)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from nibabel>=3.2.1->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (21.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.5->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.5->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (7.1.2)
# Collecting regex>=2021.8.3
#   Downloading regex-2021.11.10-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (749 kB)
#      |████████████████████████████████| 749 kB 58.5 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->nibabel>=3.2.1->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.1.5->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.1.5->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (2018.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.17.2->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (1.2.0)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.17.2->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (2.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.17.2->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (2021.11.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.17.2->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.17.2->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.17.2->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->openvino-dev==2021.4.2->-r openvino.txt (line 6)) (3.0.0)
# Building wheels for collected packages: progress, py-cpuinfo
#   Building wheel for progress (setup.py) ... done
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9632 sha256=6fce67f341c6697c4dd27cccfd1a644e5b5a977de1c9145e1f998eee0b0394ce
#   Stored in directory: /root/.cache/pip/wheels/8e/d7/61/498d8e27dc11e9805b01eb3539e2ee344436fc226daeb5fe87
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=b2705882466efe227819d24094c389b76ed52737b002dcfb19ad8a2fd9bc1ad3
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
# Successfully built progress py-cpuinfo
# Installing collected packages: scipy, regex, yamlloader, tokenizers, sentencepiece, requests, rawpy, pydicom, py-cpuinfo, progress, parasail, openvino, opencv-python, nltk, nibabel, fast-ctc-decode, openvino-dev, onnx
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: regex
#     Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
#   Attempting uninstall: nibabel
#     Found existing installation: nibabel 3.0.2
#     Uninstalling nibabel-3.0.2:
#       Successfully uninstalled nibabel-3.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.8.1 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed fast-ctc-decode-0.3.0 nibabel-3.2.1 nltk-3.6.7 onnx-1.10.1 opencv-python-4.5.3.56 openvino-2021.4.2 openvino-dev-2021.4.2 parasail-1.2.4 progress-1.6 py-cpuinfo-8.0.0 pydicom-2.2.2 rawpy-0.17.0 regex-2021.11.10 requests-2.26.0 scipy-1.5.4 sentencepiece-0.1.96 tokenizers-0.11.2 yamlloader-1.1.0

# %%
# !python tools/train.py    # Train PADIM on MVTec leather
# Out:
# Traceback (most recent call last):
#   File "tools/train.py", line 24, in <module>
#     from pytorch_lightning import Trainer, seed_everything
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/__init__.py", line 20, in <module>
#     from pytorch_lightning import metrics  # noqa: E402
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/__init__.py", line 15, in <module>
#     from pytorch_lightning.metrics.classification import (  # noqa: F401
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/classification/__init__.py", line 14, in <module>
#     from pytorch_lightning.metrics.classification.accuracy import Accuracy  # noqa: F401
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/classification/accuracy.py", line 18, in <module>
#     from pytorch_lightning.metrics.utils import deprecated_metrics
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/utils.py", line 29, in <module>
#     from pytorch_lightning.utilities import rank_zero_deprecation
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/__init__.py", line 18, in <module>
#     from pytorch_lightning.utilities.apply_func import move_data_to_device  # noqa: F401
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/apply_func.py", line 29, in <module>
#     if _compare_version("torchtext", operator.ge, "0.9.0"):
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/imports.py", line 53, in _compare_version
#     pkg = importlib.import_module(package)
#   File "/usr/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/usr/local/lib/python3.7/dist-packages/torchtext/__init__.py", line 5, in <module>
#     from . import vocab
#   File "/usr/local/lib/python3.7/dist-packages/torchtext/vocab/__init__.py", line 11, in <module>
#     from .vocab_factory import (
#   File "/usr/local/lib/python3.7/dist-packages/torchtext/vocab/vocab_factory.py", line 4, in <module>
#     from torchtext._torchtext import (
# ImportError: /usr/local/lib/python3.7/dist-packages/torchtext/_torchtext.so: undefined symbol: _ZTVN5torch3jit6MethodE
