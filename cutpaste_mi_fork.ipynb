# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsoy/ALOCC-CVPR2018/blob/master/cutpaste_mi_fork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # https://github.com/Runinho/pytorch-cutpaste

# %%
git clone https://github.com/Runinho/pytorch-cutpaste.git
# Out:
# Cloning into 'pytorch-cutpaste'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 213 (delta 39), reused 36 (delta 36), pack-reused 170
# Receiving objects: 100% (213/213), 817.70 KiB | 4.09 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %%
cd /content/pytorch-cutpaste/
# Out:
# /content/pytorch-cutpaste

# %%
pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2955 sha256=1f7e64bca49bc431a489252ea4d47afdd8425ae9b9ad7261316b51ad81148f55
#   Stored in directory: /root/.cache/pip/wheels/f8/e0/3d/9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd  /content/drive/MyDrive/Data/
# Out:
# /content/drive/MyDrive/Data

# %%
import cv2
img = cv2.imread("hazelnut/train/good/aume0.PNG")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

import matplotlib.pyplot as plt
plt.imshow(img)

# %%
cd /content/pytorch-cutpaste/
# Out:
# /content/pytorch-cutpaste

# %%
# !python run_training.py --model_dir models --head_layer 2
# Out:
# 2023-04-08 21:25:26.886692: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-08 21:25:28.032489: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Namespace(type='all', epochs=256, model_dir='models', pretrained=True, test_epochs=10, freeze_resnet=20, lr=0.03, optim='sgd', batch_size=64, head_layer=2, variant='3way', cuda=False, workers=8)
# using device: cpu
# training bottle
# loading images
# loaded 0 images
# ...
