# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsoy/ALOCC-CVPR2018/blob/master/yolov5_classification_funka_folder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YOLOv5 Classification Tutorial
#
# YOLOv5 supports classification tasks too. This is the official YOLOv5 classification notebook tutorial. YOLOv5 is maintained by [Ultralytics](https://github.com/ultralytics/yolov5).
#
# This notebook covers:
#
# *   Inference with out-of-the-box YOLOv5 classification on ImageNet
# *  [Training YOLOv5 classification](https://blog.roboflow.com//train-YOLOv5-classification-custom-data) on custom data
#
# *Looking for custom data? Explore over 66M community datasets on [Roboflow Universe](https://universe.roboflow.com).*
#
# This notebook was created with Google Colab. [Click here](https://colab.research.google.com/drive/1FiSNz9f_nT8aFtDEU3iDAQKlPT8SCVni?usp=sharing) to run it.

# %% [markdown]
# # Setup
#
# Pull in respective libraries to prepare the notebook environment.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 34.6/107.7 GB disk)

# %% [markdown]
# # 1. Infer on ImageNet
#
# To demonstrate YOLOv5 classification, we'll leverage an already trained model. In this case, we'll download the ImageNet trained models pretrained on ImageNet using YOLOv5 Utils.

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-cls' for x in p5]  # classification models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5n-cls.pt to weights/yolov5n-cls.pt...
#   0%|          | 0.00/4.87M [00:00<?, ?B/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s-cls.pt to weights/yolov5s-cls.pt...
#   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m-cls.pt to weights/yolov5m-cls.pt...
#   0%|          | 0.00/24.9M [00:00<?, ?B/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5l-cls.pt to weights/yolov5l-cls.pt...
#   0%|          | 0.00/50.9M [00:00<?, ?B/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5x-cls.pt to weights/yolov5x-cls.pt...
#   0%|          | 0.00/92.0M [00:00<?, ?B/s]

# %% [markdown]
# Now, we can infer on an example image from the ImageNet dataset.

# %%
#Download example image
import requests
image_url = "https://i.imgur.com/OczPfaz.jpg"
img_data = requests.get(image_url).content
with open('bananas.jpg', 'wb') as handler:
    handler.write(img_data)

# %%
#Infer using classify/predict.py
# !python classify/predict.py --weights ./weigths/yolov5s-cls.pt --source bananas.jpg
# Out:
# classify/predict: weights=['./weigths/yolov5s-cls.pt'], source=bananas.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s-cls.pt to weigths/yolov5s-cls.pt...
# 100% 10.5M/10.5M [00:00<00:00, 87.8MB/s]
#
# Fusing layers...
# Model summary: 117 layers, 5447688 parameters, 0 gradients, 11.4 GFLOPs
# image 1/1 /content/yolov5/bananas.jpg: 224x224 banana 0.96, zucchini 0.00, acorn squash 0.00, spaghetti squash 0.00, green mamba 0.00, 37.1ms
# Speed: 0.1ms pre-process, 37.1ms inference, 4.7ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp

# %%
#Infer using classify/predict.py
# !python classify/predict.py --weights ./weigths/yolov5s-cls.pt --source bananas.jpg
# Out:
# classify/predict: weights=['./weigths/yolov5s-cls.pt'], source=bananas.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 117 layers, 5447688 parameters, 0 gradients, 11.4 GFLOPs
# image 1/1 /content/yolov5/bananas.jpg: 224x224 banana 0.96, zucchini 0.00, acorn squash 0.00, spaghetti squash 0.00, green mamba 0.00, 35.6ms
# Speed: 0.1ms pre-process, 35.6ms inference, 0.1ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp2

# %%
#Infer using classify/predict.py
#!python classify/predict.py --weights ./weigths/yolov5s-cls.pt --source bananas.jpg

# %%
#Infer using classify/predict.py
#!python classify/predict.py --weights ./weigths/yolov5s-cls.pt --source bananas.jpg

# !python classify/predict.py --weights ./weigths/yolov5s-cls.pt --source /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato

#!python classify/predict.py --weights ./weigths/yolov5s-cls.pt --source /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/moño.jpg
# Out:
# classify/predict: weights=['./weigths/yolov5s-cls.pt'], source=/content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 117 layers, 5447688 parameters, 0 gradients, 11.4 GFLOPs
# image 1/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-102-_PNG.rf.eac8449e68ab69fbae801c54e7cef209.jpg: 224x224 conch 0.60, sulphur-crested cockatoo 0.06, hammerhead shark 0.06, flatworm 0.05, great egret 0.05, 40.5ms
# image 2/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-103-_PNG.rf.8613d9291178fd2322b4fb56dad9cd81.jpg: 224x224 flatworm 0.27, conch 0.22, barrette 0.07, sea slug 0.05, hammerhead shark 0.02, 39.9ms
# image 3/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-11-_PNG.rf.b8c1d87bb0b9cfe015e475b63d2eec04.jpg: 224x224 conch 0.58, lampshade 0.02, jellyfish 0.02, candle 0.02, necklace 0.02, 33.3ms
# image 4/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-114-_PNG.rf.11b6ede26df09461e4a826b3537f2d7a.jpg: 224x224 conch 0.58, flatworm 0.07, great egret 0.04, hammerhead shark 0.03, barrette 0.02, 34.1ms
# image 5/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-124-_PNG.rf.4e4d7b55f5810be6c115da6013fc7c28.jpg: 224x224 conch 0.33, jellyfish 0.16, barrette 0.10, great egret 0.02, horizontal bar 0.02, 34.2ms
# image 6/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-133-_PNG.rf.1a905f13e8938f8395fda330defc6891.jpg: 224x224 conch 0.47, barrette 0.07, flatworm 0.07, great egret 0.05, hammerhead shark 0.03, 36.6ms
# image 7/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-138-_PNG.rf.c1366b7262bd230ca7e79af6653870a3.jpg: 224x224 conch 0.60, jellyfish 0.10, great egret 0.03, chambered nautilus 0.01, flatworm 0.01, 33.3ms
# image 8/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-14-_PNG.rf.32283ef7ed7bc205ddccd80d9eb712b0.jpg: 224x224 conch 0.27, jellyfish 0.13, sea slug 0.11, barrette 0.10, flatworm 0.05, 33.7ms
# image 9/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-142-_PNG.rf.7eda51fc3c2cee51a208ed4d5bff0d69.jpg: 224x224 conch 0.56, jellyfish 0.05, handkerchief 0.03, lampshade 0.03, bib 0.02, 34.0ms
# image 10/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-42-_PNG.rf.3e53dc265924d0cd1cbe43dfb100e638.jpg: 224x224 barrette 0.20, jellyfish 0.15, conch 0.07, great egret 0.04, chambered nautilus 0.03, 34.6ms
# image 11/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-43-_PNG.rf.3afbfc6b48cab730e867ba5d5bbd08dc.jpg: 224x224 barrette 0.24, conch 0.21, flatworm 0.10, sea slug 0.05, great egret 0.05, 37.9ms
# image 12/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-51-_PNG.rf.01045210c1181a3c120415ed427db468.jpg: 224x224 conch 0.25, barrette 0.09, flatworm 0.06, chambered nautilus 0.04, nematode 0.04, 34.1ms
# image 13/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-53-_PNG.rf.d36df169191dc1a67558419cc63ed7b0.jpg: 224x224 conch 0.30, barrette 0.20, flatworm 0.09, great egret 0.04, sea slug 0.04, 36.8ms
# image 14/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-63-_PNG.rf.b8e50d35c75278eb6d22c27960fb87d3.jpg: 224x224 conch 0.49, jellyfish 0.07, coral fungus 0.04, great egret 0.03, barrette 0.03, 34.5ms
# image 15/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-71-_PNG.rf.97e5cd52964d21880d0dad8d1d5d8335.jpg: 224x224 conch 0.45, jellyfish 0.10, great egret 0.04, barrette 0.04, lampshade 0.03, 34.0ms
# image 16/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-89-_PNG.rf.d7488795f4e863fa9ccbef05a9bd25c4.jpg: 224x224 conch 0.62, jellyfish 0.05, coral fungus 0.03, great egret 0.02, lampshade 0.02, 38.0ms
# image 17/17 /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-99-_PNG.rf.784b2cc60b3a9b8c08840b196bf8f32d.jpg: 224x224 conch 0.31, barrette 0.11, sea slug 0.10, chambered nautilus 0.09, flatworm 0.07, 34.0ms
# Speed: 0.0ms pre-process, 35.5ms inference, 0.0ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp13

# %% [markdown]
# From the output, we can see the ImageNet trained model correctly predicts the class `banana` with `0.95` confidence.

# %% [markdown]
# ## 2. (Optional) Validate
#
# Use the `classify/val.py` script to run validation for the model. This will show us the model's performance on each class.
#
# First, we need to download ImageNet.

# %%
# # WARNING: takes ~20 minutes
# !bash data/scripts/get_imagenet.sh --val

# %%
# # run the validation script
# !python classify/val.py --weights ./weigths/yolov5s-cls.pt --data ../datasets/imagenet

# %% [markdown]
# The output shows accuracy metrics for the ImageNet validation dataset including per class accuracy.

# %% [markdown]
# # 3. Train On Custom Data
#
# To train on custom data, we need to prepare a dataset with custom labels.
#
# To prepare custom data, we'll use [Roboflow](https://roboflow.com). Roboflow enables easy dataset prep with your team, including labeling, formatting into the right export format, deploying, and active learning with a `pip` package.
#
# If you need custom data, there are over 66M open source images from the community on [Roboflow Universe](https://universe.roboflow.com).
#
# (For more guidance, here's a detailed blog on [training YOLOv5 classification on custom data](https://blog.roboflow.com/train-YOLOv5-classification-custom-data).)
#
#
# Create a free Roboflow account, upload your data, and label.
#
# ![](https://s4.gifyu.com/images/fruit-labeling.gif)

# %% [markdown]
# ### Load Custom Dataset
#
# Next, we'll export our dataset into the right directory structure for training YOLOv5 classification to load into this notebook. Select the `Export` button at the top of the version page, `Folder Structure` type, and `show download code`.
#
# The ensures all our directories are in the right format:
#
# ```
# dataset
# ├── train
# │   ├── class-one
# │   │   ├── IMG_123.jpg
# │   └── class-two
# │       ├── IMG_456.jpg
# ├── valid
# │   ├── class-one
# │   │   ├── IMG_789.jpg
# │   └── class-two
# │       ├── IMG_101.jpg
# ├── test
# │   ├── class-one
# │   │   ├── IMG_121.jpg
# │   └── class-two
# │       ├── IMG_341.jpg
# ```
#
# ![](https://i.imgur.com/BF9BNR8.gif)
#
#
# Copy and paste that snippet into the cell below.

# %%
# Ensure we're in the right directory to download our custom dataset
import os
os.makedirs("../datasets/", exist_ok=True)
# %cd ../datasets/
# Out:
# /content/datasets

# %%
# REPLACE the below with your exported code snippet from above


# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="9ORhusQxYFimZzVYfjdC")
project = rf.workspace("new-workspace-lzcyx").project("bow-pasta-yolo_v5")
dataset = project.version(1).download("folder")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting roboflow
#   Downloading roboflow-0.2.29-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 KB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.8/dist-packages (from roboflow) (4.6.0.66)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 4.1 MB/s eta 0:00:00
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from roboflow) (3.2.2)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.8/dist-packages (from roboflow) (4.0.0)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting urllib3>=1.26.6
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.8/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from roboflow) (6.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.8/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.8/dist-packages (from roboflow) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from roboflow) (1.15.0)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.8/dist-packages (from roboflow) (2022.12.7)
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from roboflow) (2.25.1)
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.8/dist-packages (from roboflow) (1.21.6)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.8/dist-packages (from roboflow) (4.64.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from roboflow) (2.8.2)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=3d79dd5ff61fe8cf8b3a5c610879593ce06445a6f06b347cbf035a46e730b9d5
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: wget, urllib3, python-dotenv, pyparsing, cycler, requests-toolbelt, roboflow
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
# Successfully installed cycler-0.10.0 pyparsing-2.4.7 python-dotenv-0.21.1 requests-toolbelt-0.10.1 roboflow-0.2.29 urllib3-1.26.14 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in bow-pasta-yolo_v5-1 to folder: 100% [2708925 / 2708925] bytes
# Extracting Dataset Version Zip to bow-pasta-yolo_v5-1 in folder:: 100%|██████████| 335/335 [00:00<00:00, 1959.80it/s]

# %%
#Save the dataset name to the environment so we can use it in a system call later
dataset_name = dataset.location.split(os.sep)[-1]
os.environ["/content/datasets"] = dataset_name

# %% [markdown]
# ### Train On Custom Data 🎉
# Here, we use the DATASET_NAME environment variable to pass our dataset to the `--data` parameter.
#
# Note: we're training for 100 epochs here. We're also starting training from the pretrained weights. Larger datasets will likely benefit from longer training.

# %%
# %cd ../yolov5
# !python classify/train.py --model yolov5s-cls.pt --data /content/datasets/bow-pasta-yolo_v5-1  --epochs 10 --img 128 --pretrained weights/yolov5s-cls.pt
# Out:
# /content/yolov5
# classify/train: model=yolov5s-cls.pt, data=/content/datasets/bow-pasta-yolo_v5-1, epochs=10, batch_size=64, imgsz=128, nosave=False, cache=None, device=, workers=8, project=runs/train-cls, name=exp, exist_ok=False, pretrained=weights/yolov5s-cls.pt, optimizer=Adam, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# TensorBoard: Start with 'tensorboard --logdir runs/train-cls', view at http://localhost:6006/
# albumentations: RandomResizedCrop(p=1.0, height=128, width=128, scale=(0.08, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=[0, 0]), Normalize(p=1.0, mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s-cls.pt to yolov5s-cls.pt...
# 100% 10.5M/10.5M [00:00<00:00, 88.0MB/s]
#
# Model summary: 149 layers, 4175042 parameters, 4175042 gradients, 10.5 GFLOPs
# optimizer: Adam(lr=0.001) with parameter groups 32 weight(decay=0.0), 33 weight(decay=5e-05), 33 bias
# Image sizes 128 train, 128 test
# Using 1 dataloader workers
# Logging results to runs/train-cls/exp
# Starting yolov5s-cls.pt training on /content/datasets/bow-pasta-yolo_v5-1 dataset with 2 classes for 10 epochs...
#
#      Epoch   GPU_mem  train_loss   test_loss    top1_acc    top5_acc
#       1/10        0G       0.936       0.696       0.469           1: 100% 4/4 [00:09<00:00,  2.32s/it]
#       2/10        0G         0.7       0.699       0.469           1: 100% 4/4 [00:08<00:00,  2.24s/it]
#       3/10        0G        0.67       0.701       0.469           1: 100% 4/4 [00:08<00:00,  2.24s/it]
#       4/10        0G       0.698       0.704       0.469           1: 100% 4/4 [00:08<00:00,  2.24s/it]
#       5/10        0G       0.687       0.698       0.469           1: 100% 4/4 [00:08<00:00,  2.22s/it]
#       6/10        0G       0.667       0.698       0.469           1: 100% 4/4 [00:09<00:00,  2.27s/it]
#       7/10        0G       0.663       0.699       0.469           1: 100% 4/4 [00:08<00:00,  2.24s/it]
#       8/10        0G        0.67       0.698       0.469           1: 100% 4/4 [00:09<00:00,  2.28s/it]
#       9/10        0G       0.655       0.697       0.469           1: 100% 4/4 [00:09<00:00,  2.37s/it]
#      10/10        0G       0.683       0.696       0.469           1: 100% 4/4 [00:09<00:00,  2.32s/it]
#
# Training complete (0.026 hours)
# Results saved to runs/train-cls/exp
# Predict:         python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source im.jpg
# Validate:        python classify/val.py --weights runs/train-cls/exp/weights/best.pt --data /content/datasets/bow-pasta-yolo_v5-1
# Export:          python export.py --weights runs/train-cls/exp/weights/best.pt --include onnx
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', 'runs/train-cls/exp/weights/best.pt')
# Visualize:       https://netron.app

# %% [markdown]
# ### Validate Your Custom Model
#
# Repeat step 2 from above to test and validate your custom model.

# %%
# %cd ../yolov5
# Out:
# /content/yolov5

# %%
# !python classify/val.py --weights runs/train-cls/exp/weights/best.pt --data /content/datasets/bow-pasta-yolo_v5-1/valid/yellow-tomato/bad-106-_PNG.rf.42bac6d88839333034811dc215ebf800.jpg
# Out:
# classify/val: data=/content/datasets/bow-pasta-yolo_v5-1/valid/yellow-tomato/bad-106-_PNG.rf.42bac6d88839333034811dc215ebf800.jpg, weights=['runs/train-cls/exp/weights/best.pt'], batch_size=128, imgsz=224, device=, workers=8, verbose=True, project=runs/val-cls, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
# Traceback (most recent call last):
#   File "classify/val.py", line 170, in <module>
#     main(opt)
#   File "classify/val.py", line 165, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "classify/val.py", line 92, in run
#     dataloader = create_classification_dataloader(path=test_dir,
#   File "/content/yolov5/utils/dataloaders.py", line 1207, in create_classification_dataloader
#     dataset = ClassificationDataset(root=path, imgsz=imgsz, augment=augment, cache=cache)
#   File "/content/yolov5/utils/dataloaders.py", line 1173, in __init__
#     super().__init__(root=root)
#   File "/usr/local/lib/python3.8/dist-packages/torchvision/datasets/folder.py", line 309, in __init__
#     super().__init__(
#   File "/usr/local/lib/python3.8/dist-packages/torchvision/datasets/folder.py", line 144, in __init__
#     classes, class_to_idx = self.find_classes(self.root)
#   File "/usr/local/lib/python3.8/dist-packages/torchvision/datasets/folder.py", line 218, in find_classes
#     return find_classes(directory)
#   File "/usr/local/lib/python3.8/dist-packages/torchvision/datasets/folder.py", line 40, in find_classes
#     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
# NotADirectoryError: [Errno 20] Not a directory: '/content/datasets/bow-pasta-yolo_v5-1/valid/yellow-tomato/bad-106-_PNG.rf.42bac6d88839333034811dc215ebf800.jpg/val'

# %% [markdown]
# ### Infer With Your Custom Model

# %%
# %cd ../yolov5
# Out:
# /content/yolov5

# %%
#Infer
# !python classify/predict.py --weights runs/train-cls/exp5/weights/best.pt --source /content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-14-_PNG.rf.32283ef7ed7bc205ddccd80d9eb712b0.jpg
# Out:
# classify/predict: weights=['runs/train-cls/exp5/weights/best.pt'], source=/content/datasets/bow-pasta-yolo_v5-1/test/yellow-tomato/bad-14-_PNG.rf.32283ef7ed7bc205ddccd80d9eb712b0.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Traceback (most recent call last):
#   File "classify/predict.py", line 226, in <module>
#     main(opt)
#   File "classify/predict.py", line 221, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "classify/predict.py", line 90, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/content/yolov5/models/common.py", line 345, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#   File "/content/yolov5/models/experimental.py", line 79, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 251, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train-cls/exp5/weights/best.pt'

# %%
#Get the path of an image from the test or validation set
if os.path.exists(os.path.join(dataset.location, "test")):
  split_path = os.path.join(dataset.location, "test")
else:
  os.path.join(dataset.location, "valid")
example_class = os.listdir(split_path)[0]
example_image_name = os.listdir(os.path.join(split_path, example_class))[0]
example_image_path = os.path.join(split_path, example_class, example_image_name)
os.environ["TEST_IMAGE_PATH"] = example_image_path
# colocar direccion de la foto a inferir dentro de comillas

print(f"Inferring on an example of the class '{example_class}'")

#Infer
# !python classify/predict.py --weights runs/train-cls/exp5/weights/best.pt --source /content/datasets/bow-pasta-yolo_v5-1/valid/yellow-tomato/bad-105-_PNG.rf.9369c49aa15c90e4836d8d3924982f7b.jpg
# Out:
# Inferring on an example of the class 'red-tomato'
# classify/predict: weights=['runs/train-cls/exp5/weights/best.pt'], source=/content/datasets/bow-pasta-yolo_v5-1/valid/yellow-tomato/bad-105-_PNG.rf.9369c49aa15c90e4836d8d3924982f7b.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Traceback (most recent call last):
#   File "classify/predict.py", line 226, in <module>
#     main(opt)
#   File "classify/predict.py", line 221, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "classify/predict.py", line 90, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/content/yolov5/models/common.py", line 345, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#   File "/content/yolov5/models/experimental.py", line 79, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 251, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train-cls/exp5/weights/best.pt'

# %% [markdown]
# We can see the inference results show ~3ms inference and the respective classes predicted probabilities.

# %% [markdown]
# ## (OPTIONAL) Improve Our Model with Active Learning
#
# Now that we've trained our model once, we will want to continue to improve its performance. Improvement is largely dependent on improving our dataset.
#
# We can programmatically upload example failure images back to our custom dataset based on conditions (like seeing an underrpresented class or a low confidence score) using the same `pip` package.

# %%
# # Upload example image
# project.upload(image_path)

# %%
# # Example upload code 
# min_conf = float("inf")
# for pred in results:
#     if pred["score"] < min_conf:
#         min_conf = pred["score"]
# if min_conf < 0.4:
#     project.upload(image_path)

# %% [markdown]
# # (BONUS) YOLOv5 classify/predict.py Accepts Several Input Methods
# - Webcam: `python classify/predict.py --weights yolov5s-cls.pt --source 0`
# - Image `python classify/predict.py --weights yolov5s-cls.pt --source img.jpg`
# - Video: `python classify/predict.py --weights yolov5s-cls.pt --source vid.mp4`
# - Directory: `python classify/predict.py --weights yolov5s-cls.pt --source path/`
# - Glob: `python classify/predict.py --weights yolov5s-cls.pt --source 'path/*.jpg'`
# - YouTube: `python classify/predict.py --weights yolov5s-cls.pt --source 'https://youtu.be/Zgi9g1ksQHc'`
# - RTSP, RTMP, HTTP stream: `python classify/predict.py --weights yolov5s-cls.pt --source 'rtsp://example.com/media.mp4'`

# %% [markdown]
# ###Directory Example

# %%
# la proxima celda falla, no hay modelo:FileNotFoundError: [Errno 2] No such file or directory: 'runs/train-cls/exp/weights/best.pt'

# %%
#Directory infer
os.environ["TEST_CLASS_PATH"] = test_class_path = os.path.join(*os.environ["TEST_IMAGE_PATH"].split(os.sep)[:-1])
print(f"Infering on all images from the directory {os.environ['TEST_CLASS_PATH']}")
# !python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source /$TEST_CLASS_PATH/
# Out:
# Infering on all images from the directory content/datasets/bow-pasta-yolo_v5-1/test/red-tomato
# classify/predict: weights=['runs/train-cls/exp/weights/best.pt'], source=/content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
# image 1/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-115-_PNG.rf.f424748c205fb520a2cc533575ab3c20.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.8ms
# image 2/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-124-_PNG.rf.ceba7acc194ee642af923e653d01c699.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# image 3/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-135-_PNG.rf.a4a364d444c2ee9331c7b7e1f66f06ef.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.1ms
# image 4/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-146-_PNG.rf.17534ac1503de75329405cf091bcb60c.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.8ms
# image 5/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-155-_PNG.rf.2cb861fbc6c47e3997fb52d801a2781d.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.4ms
# image 6/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-16-_PNG.rf.72557abf7f4ba1e28ecd8a3eeba0da75.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# image 7/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-19-_PNG.rf.20225f1dd3a272b1357fc76c76ba60f6.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.8ms
# image 8/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-22-_PNG.rf.47c23f7661e26a6be031aa090c2981e0.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.7ms
# image 9/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-33-_PNG.rf.efe56e2f80d7ed33bd0ba158897ad7a1.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# image 10/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-45-_PNG.rf.2e9867f519802fb50c1de22b98201f48.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.9ms
# image 11/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-50-_PNG.rf.1ce6c61e5b100f9bb1270c3d5d9e0fc9.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# image 12/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-54-_PNG.rf.d5e5b3024b0e9f0075520803f68039a8.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# image 13/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-70-_PNG.rf.3e57edb7094c7128738c605b031da885.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# image 14/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-85-_PNG.rf.8eb51a7f102451b2bd08109754a38c1e.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# image 15/15 /content/datasets/bow-pasta-yolo_v5-1/test/red-tomato/ok-98-_PNG.rf.e483bba4682559e148e429043356caa4.jpg: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.7ms
# Speed: 0.0ms pre-process, 36.5ms inference, 0.0ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp6

# %% [markdown]
# ###YouTube Example

# %%
#YouTube infer
# !python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source 'https://www.youtube.com/watch?v=7AlYA4ItA74'
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 48.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 49.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 51.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 45.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 52.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 52.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 52.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 52.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 45.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 59.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 54.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 52.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 66.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 49.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 48.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 51.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 56.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 48.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 53.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 48.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 45.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 45.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 51.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 49.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 62.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 52.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 56.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 56.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 45.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 54.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 45.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 45.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 51.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 48.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 53.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 63.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 54.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 62.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 53.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 51.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 50.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 55.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 57.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 50.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 52.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 71.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 51.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 56.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 58.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.6ms
# ...
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 49.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 54.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 57.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 69.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 52.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 52.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 48.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 51.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 49.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 65.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 55.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 53.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 49.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 59.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 72.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 49.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 50.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 46.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 53.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.5ms
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 47.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 54.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 31.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 38.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 39.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 44.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 32.7ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 37.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 43.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 42.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.3ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.9ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 36.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.8ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 41.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.0ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.4ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.1ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 34.6ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 35.5ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 33.2ms
# 0: 224x224 red-tomato 0.52, yellow-tomato 0.48, 40.0ms
# Speed: 0.0ms pre-process, 37.7ms inference, 0.0ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp7
