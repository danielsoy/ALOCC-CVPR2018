# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsoy/ALOCC-CVPR2018/blob/master/malaria_cell_images_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##  https://www.kaggle.com/sauravbhuyan/malaria-cell-images-detection

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2

img = cv2.imread("../content/drive/MyDrive/boteya malaria/Parasitized/anomalo.jpg")
img.shape
# Out:
# (480, 640, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)

# %%
img_dir = "../content/drive/MyDrive/boteya malaria"

# %%
import tensorflow as tf

train_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale= 1/255.,                                                                                                                   
                                                           rotation_range=0.2,
                                                           width_shift_range=0.2,
                                                           height_shift_range=0.2,
                                                           zoom_range = 0.2, 
                                                           horizontal_flip=True,
                                                           validation_split = 0.25
                                                            )
test_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale= 1/255.,
                                                          validation_split = 0.25
                                                          )

# %%
train_data = train_gen.flow_from_directory(img_dir,
                                           target_size = (224,224),
                                           class_mode = "categorical",
                                           batch_size = 32,
                                           classes = ["Parasitized","Uninfected"],
                                           seed = 42,
                                           subset = "training"                                           
                                           )
test_data = test_gen.flow_from_directory(img_dir,
                                         target_size = (224,224),
                                         class_mode = "categorical",
                                         classes = ["Parasitized","Uninfected"],
                                         batch_size = 32,
                                         seed = 42,
                                         subset = "validation"
                                         )
# Out:
# Found 688 images belonging to 2 classes.
# Found 228 images belonging to 2 classes.

# %%
class_labels = list(train_data.class_indices.keys())

class_labels
# Out:
# ['Parasitized', 'Uninfected']

# %%
image,label = train_data.next()
print(image.shape)
print(label.shape)
# Out:
# (32, 224, 224, 3)
# (32, 2)

# %%
# visualizing the train data

import matplotlib.pyplot as plt
import tensorflow as tf

plt.figure(figsize=(16,16))

for i in range(18):

  image,label = train_data.next()

  plt.subplot(6,3,i+1)
  plt.imshow(image[i])
  plt.title(class_labels[tf.argmax(label[i])])
  plt.axis("off")

# %%
#building a CNN model
import tensorflow as tf
from tensorflow.keras import layers

model = tf.keras.Sequential([
                             layers.Conv2D(filters=64, kernel_size= 2, activation="relu", input_shape=(224,224,3)),
                             layers.MaxPooling2D(pool_size= 2),

                             layers.Conv2D(filters= 64, kernel_size= 2, activation="relu"),
                             layers.MaxPooling2D(pool_size= 2),

                             layers.Conv2D(filters= 64, kernel_size= 2, activation= "relu"),
                             layers.MaxPooling2D(pool_size = 2),


                             layers.Flatten(),

                             layers.Dense(128, activation= "relu"),
                             layers.Dropout(0.5),
                             layers.Dense(2, activation="softmax"),
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 223, 223, 64)      832
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 110, 110, 64)      16448
#
#  max_pooling2d_1 (MaxPooling  (None, 55, 55, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 54, 54, 64)        16448
#
#  max_pooling2d_2 (MaxPooling  (None, 27, 27, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 46656)             0
#
#  dense (Dense)               (None, 128)               5972096
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 6,006,082
# Trainable params: 6,006,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling the model

model.compile(
    loss = tf.keras.losses.categorical_crossentropy,
    optimizer = tf.keras.optimizers.Adam(learning_rate= 0.001),
    metrics = ["accuracy"]
)

# %%
# fitting data to the model
model.fit(train_data,
          epochs = 50,
          steps_per_epoch = len(train_data),
          validation_data = test_data,
          validation_steps = len(test_data)
          )
# Out:
# Epoch 1/50
# 22/22 [==============================] - 15s 680ms/step - loss: 0.2663 - accuracy: 0.8953 - val_loss: 0.4969 - val_accuracy: 0.6184
# Epoch 2/50
# 22/22 [==============================] - 15s 672ms/step - loss: 0.2457 - accuracy: 0.9099 - val_loss: 0.3985 - val_accuracy: 0.6667
# Epoch 3/50
# 22/22 [==============================] - 15s 670ms/step - loss: 0.1872 - accuracy: 0.9128 - val_loss: 0.3804 - val_accuracy: 0.8158
# Epoch 4/50
# 22/22 [==============================] - 15s 667ms/step - loss: 0.2112 - accuracy: 0.9026 - val_loss: 0.3394 - val_accuracy: 0.8026
# Epoch 5/50
# 22/22 [==============================] - 15s 661ms/step - loss: 0.1894 - accuracy: 0.9113 - val_loss: 0.4924 - val_accuracy: 0.7149
# Epoch 6/50
# 22/22 [==============================] - 15s 663ms/step - loss: 0.1926 - accuracy: 0.9186 - val_loss: 0.2889 - val_accuracy: 0.8202
# Epoch 7/50
# 22/22 [==============================] - 14s 653ms/step - loss: 0.1902 - accuracy: 0.9201 - val_loss: 0.1295 - val_accuracy: 0.9912
# Epoch 8/50
# 22/22 [==============================] - 15s 663ms/step - loss: 0.2364 - accuracy: 0.9026 - val_loss: 0.4183 - val_accuracy: 0.6930
# Epoch 9/50
# Epoch 32/50
# 22/22 [==============================] - 15s 681ms/step - loss: 0.1333 - accuracy: 0.9404 - val_loss: 0.0570 - val_accuracy: 0.9868
# Epoch 33/50
# 22/22 [==============================] - 15s 683ms/step - loss: 0.1403 - accuracy: 0.9462 - val_loss: 0.0539 - val_accuracy: 0.9956
# Epoch 34/50
# 22/22 [==============================] - 15s 684ms/step - loss: 0.1170 - accuracy: 0.9549 - val_loss: 0.0227 - val_accuracy: 0.9956
# Epoch 35/50
# 22/22 [==============================] - 15s 660ms/step - loss: 0.1190 - accuracy: 0.9433 - val_loss: 0.0719 - val_accuracy: 0.9825
# Epoch 36/50
# 22/22 [==============================] - 15s 663ms/step - loss: 0.1089 - accuracy: 0.9549 - val_loss: 0.0482 - val_accuracy: 0.9825
# Epoch 37/50
# 22/22 [==============================] - 15s 665ms/step - loss: 0.1050 - accuracy: 0.9593 - val_loss: 0.0414 - val_accuracy: 0.9912
# Epoch 38/50
# 22/22 [==============================] - 15s 674ms/step - loss: 0.1111 - accuracy: 0.9549 - val_loss: 0.0521 - val_accuracy: 0.9868
# Epoch 39/50
# 22/22 [==============================] - 15s 675ms/step - loss: 0.0972 - accuracy: 0.9651 - val_loss: 0.0621 - val_accuracy: 0.9868
# Epoch 40/50
# 22/22 [==============================] - 14s 652ms/step - loss: 0.1119 - accuracy: 0.9477 - val_loss: 0.0417 - val_accuracy: 0.9868
# Epoch 41/50
# 22/22 [==============================] - 14s 653ms/step - loss: 0.0847 - accuracy: 0.9724 - val_loss: 0.1059 - val_accuracy: 0.9649
# Epoch 42/50
# 22/22 [==============================] - 14s 650ms/step - loss: 0.1178 - accuracy: 0.9535 - val_loss: 0.1748 - val_accuracy: 0.8816
# Epoch 43/50
# 22/22 [==============================] - 15s 668ms/step - loss: 0.1287 - accuracy: 0.9448 - val_loss: 0.0780 - val_accuracy: 0.9868
# Epoch 44/50
# 22/22 [==============================] - 14s 656ms/step - loss: 0.1101 - accuracy: 0.9637 - val_loss: 0.1532 - val_accuracy: 0.9474
# Epoch 45/50
# 22/22 [==============================] - 15s 658ms/step - loss: 0.1294 - accuracy: 0.9578 - val_loss: 0.1896 - val_accuracy: 0.9474
# Epoch 46/50
# 22/22 [==============================] - 14s 656ms/step - loss: 0.1060 - accuracy: 0.9578 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 47/50
# 22/22 [==============================] - 15s 660ms/step - loss: 0.1000 - accuracy: 0.9651 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 48/50
# 22/22 [==============================] - 14s 656ms/step - loss: 0.0946 - accuracy: 0.9622 - val_loss: 0.1066 - val_accuracy: 0.9561
# Epoch 49/50
# 22/22 [==============================] - 15s 658ms/step - loss: 0.1105 - accuracy: 0.9637 - val_loss: 0.0832 - val_accuracy: 0.9737
# Epoch 50/50
# 22/22 [==============================] - 15s 674ms/step - loss: 0.0849 - accuracy: 0.9637 - val_loss: 0.0141 - val_accuracy: 1.0000

# %%
model_evaluation = model.evaluate(test_data)
# Out:
# 8/8 [==============================] - 2s 203ms/step - loss: 0.0141 - accuracy: 1.0000

# %%
print(f"Model Accuracy: {model_evaluation[1] * 100:.2f} %")
# Out:
# Model Accuracy: 100.00 %

# %%
# save model and architecture to single file
model.save("boteyamalaria.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# serialize model to JSON
model_json = model.to_json()
with open("boteyamalaria.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("boteyamalara1.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# visualizing the train data

import matplotlib.pyplot as plt
import tensorflow as tf

plt.figure(figsize=(16,16))

for i in range(18):

  image,label = train_data.next()

  model_pred = model.predict(image)

  plt.subplot(6,3,i+1)
  plt.imshow(image[i])
  plt.title(f"Prediction : {class_labels[tf.argmax(model_pred[i])]}\n Original : {class_labels[tf.argmax(label[i])]}")
  plt.subplots_adjust(top = 1.25)
  plt.axis("off")
